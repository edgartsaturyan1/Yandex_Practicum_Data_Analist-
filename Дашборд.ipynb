# %% [markdown]
# Ссылка на дашборд - https://public.tableau.com/views/Dashboardofproducts_16813265775660/Dashboardofproducts?:language=en-US&publish=yes&:display_count=n&:origin=viz_share_link

# %% [markdown]
# <div class='alert alert-success'> 👍
# Спасибо за работу! Дашборд принят, все критерии соблюдены
