# %% [markdown]
# <div class="alert alert-info">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Привет Эд! Меня зовут Марат, и я буду твоим ревьюером. Спешу сообщить что все ключевые этапы в работе выполнены,  с задачей тебе удалось справиться. По поводу обращения - в IT сфере принято общаться на «ты» :) Но, если привычней на «вы», дай знать. Как ревьюера моя задача помочь тебе в развитии, дав хорошие советы. Я внимательно посмотрю твой код, ознакомлюсь с твоими выводами и оставлю комментарии. Где то могу предложить небольшие исправление в коде, но ненавязчиво. Где потребуются уточнения, я оставлю много наводящих вопросов. Они помогут тебя с поиском верного решения.
#
# Все мои комментарии размечены по цветам, для лучшего восприятия.
#
# <div class="alert alert-success">Зеленым цветом и словом «Успех» отмечены особо удачные и элегантные решения, которыми ты можешь гордиться. </div>
#
# <div class="alert alert-warning">Желтым и значком словом «Совет», помечены решения у которых есть альтернативные решения, более оптимальные. Ты можешь найти их сразу и доработать проект, или отложить это на потом, для будущих проектах. Проект будет принят и без их доработки. </div>
#
# <div class="alert alert-danger"> Красным цветом и значком словом «Ошибка» помечу твои решения, на которые стоит обратить внимание прежде всего. После их доработки проект будет принят. </div>
#
# Залог успеха - работа сообща, взаимное уважение и работа в диалоге. Поэтому, помечай свои ответные комментарии на мои реплики заметным цветом или курсивом, так мне будет легче их отслеживать. Пожалуйста, не изменяй и не удаляй мои комментарии. Все это поможет выполнить повторную проверку быстрей.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Ошибка:
#
#
# Вступление в работу очень важно, так человек, который смотрит твой проект (и на работе в том числе) будет сразу введен в курс дела.
#
#
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-dark" role="alert">
#
# Перед нами стоит миссия по выявлению особенностей и закономерностей на рынке игровой индустрии, для дальнейшего планирование рекламной кампании и выявления потенциально успешного продукта на 2017 год. Входные данные — открытые источники данных о продажах игр, оценке пользователей и экспертов, жанры и платформы до 2016 года. Перед началом исследования откроем файл с данными и изучим общую информацию:

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Успех 👍:
#
#
#
# Принято
#
#
#
#
# </div>

# %% [markdown]
# # Комментарий студента
# <font color="purple"> Ошибку исправил, вступление написал!

# %% [markdown]
# # Откроем файл с данными и изучим общую информацию:

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
from scipy import stats as st
warnings.simplefilter("ignore")

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
# Собираем все импорты в верхней части, чтобы легче было ориентироваться и добавлять новые по необходимости.
#
#
# <div class="alert alert-warning">
#
# Совет:
#
#
# - кстати есть рекомендации PEP-8 при написании кода, в том числе и для импортов. Если интересно можешь почитать [тут](https://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html), это на будущее

# %% [markdown]
# # Комментарий студента
# <font color="purple"> Спасибо, добавил сайт в избранное, обязательно ознакомлюсь с PEP-8!

# %%
games = pd.read_csv('/datasets/games.csv')

# %%
games.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
games.info()
games.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# ...

# %% [markdown]
# Изучим общую информацию предоставленных данных. Мы имеем 11 столбцов и 16715 строк. Все данные предоставлены нам в двух типах: object и float64. Пропуски имеются в столбцах: name, genre, year_of_release, critic_score, user_score, rating.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
#
#
#
#
# info() - получено первичное представление о данных.
#
#
#
#
# План дальнейших действий составлен.
#
#
# <div class="alert alert-warning">
#
#
# Совет:
#
#
# - При первичном взгляде на датасет хорошо еще использовать describe (можно передать аргумент include='all', чтобы информация отображалась и по нечисленными типами данных). Почему это может быть важно? .info() дало тебе информацию о пропусках и типах данных, но вот взять sales, там тоже могут быть некорректности - например отрицательные цифры, и тут .describe() поможет.
#
#
#
#
# - .sample (выводит вразнобой) лучше .head (выводит первые строки), ведь если данные каким то образом упорядоченны, то шансы увидеть что то разнообразное через .sample чуть выше чем через .head (или .tail - выводит последние строки)

# %% [markdown]
# # Комментарий студента
# <font color="purple"> В прошлом проекте использовал describe, тут почему-то не решился... За sample спасибо, буду использовать!

# %% [markdown]
# # Подготовим данные:

# %%
for game in games:
    games = games.rename(columns = {game : game.lower()})
#games.head()

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
# Все верно, использование .lower предпочтительно в данном случаи, (ведь нас не просят переименовать а только привести к строчному виду) так мы автоматизируем работу, впереди у нас датасеты с сотнями столбцами которые нам переделывать через .rename() будет затруднительно.
#
#
# <div class="alert alert-warning">
#
#
# Совет:
#
#
#
# А вот цикл тут не нужен

# %% [markdown]
# Приведем названия столбцов к нижнему регистру через for.

# %% [markdown]
# # Комментарий студента
# <font color="purple"> Соглашусь!

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Совет 🤔:
#
# Pandas так написан, что можно вообще без циклов
#
#
#     df.columns = df.columns.str.lower()
# </div>

# %%
#games[games.name.isna()]
games = games.dropna(subset=['name']).reset_index(drop=True)

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Методы применены оптимально. Молодец
#
#
#
# <div class="alert alert-warning">
#
#
# Совет:
#
#
#
# - Если вдруг не знаешь,   удалять можно целой пачкой:
#
#     df.dropna(subset=['year_of_release', 'name', 'genre'])
#
#
#
# - Решение верное, но перед удалением стоит посмотреть на записи  может на удаленные пару строк приходится по 100 млн. продаж

# %% [markdown]
# # Комментарий студента
# <font color="purple"> Я проверял перед удалением, просто здесь не отоброзил, там было два значения, которые ничем нельзя было заменить, ни названия, ни жанра, ни года игры.

# %% [markdown]
# В столбце с названием игр отсутствуют два значения у которых нет необходимой информации для замены, поэтому их можно удалить путем dropna. Таким образом, мы также убираем пропущенные значения в столбце с жанром игр.

# %%
games = games.query('year_of_release > 1950')
games['year_of_release'] = games['year_of_release'].astype('int')

# %% [markdown]
# В столбце year_of_release есть выбивающееся значение, мешающее перевести в тип int. Уберем его через срез и преобразуем в тип int.

# %%
games['critic_score'] = games['critic_score'].fillna('-10')
games['critic_score'] = games['critic_score'].astype('float')
#games.critic_score.value_counts()

# %% [markdown]
# В столбце с оценкой критиков отсутствует 8461 значение. Заменить их на реальные оценки или удалить нельзя, так как слишком большой процент от общих данных. Поэтому все значения без оценки заменим на "-1" и дальше будет легко отследить, так как в данных нет отрицательных оценок. Также поменяем тип данных на float для дальнейших анализов в исследовании.

# %%
games['user_score'] = games['user_score'].fillna('-1')
games.loc[games['user_score'] == 'tbd', 'user_score'] = '-1'
games['user_score'] = games['user_score'].astype('float')
#games.critic_score.value_counts()

# %% [markdown]
# В столбце с оценкой пользователей отсутствует 8461 значение. Заменить их на реальные оценки или удалить нельзя, так как слишком большой процент от общих данных. Поэтому все значения без оценки заменим на "-1" и дальше будет легко отследить, так как в данных нет отрицательных оценок. Аббревиатура "TBD" расшифровывается как: To Be Determined - "Будет определено". Такое подобное сокращение можно встретить в анонсах компьютерных игр в графе "Дата выхода". Когда разработчики игры сообщают о выходе игры, но точной даты выхода нет, именно эта аббревиатура и используется. Поэтому логично их тоже заменить на "-1", таким образом заглушить их. Также поменяем тип данных на float для дальнейших анализов в исследовании.

# %%
games['rating'] = games['rating'].fillna('Unknown')
games.loc[games['rating'] == 'RP', 'rating'] = 'Unknown'
games.loc[games['rating'].isin(['K-A']), 'rating'] = 'E'
games.loc[games['rating'] == 'AO', 'rating'] = 'M'
#games.rating.value_counts()

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
# Здорово что подумал о неявных дубликтах, если похитрее, используя регулярные выражения, то можно найти дубликаты в именах, но в незначительных размерах.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Верное решение с использованием заглушки для rating, верное применение инструмента .fillna. Это тонкий момент в проекте, на котором студенты часто ошибаются, получая красное.
#
#
#
# <div class="alert alert-warning">
#
#
# Совет:
#
#
# Нет обьяснения, оно могло выглядеть так: Если посмотреть в интернете, что такое рейтинг ESRB, то узнаем что он только для Северной Америки, а в Японии CERO к примеру. То есть пропуск это не ошибка, не технический сбой, это тоже информация которую нужно привести в удобный вид.

# %% [markdown]
# # Комментарий студента
# <font color="purple"> Стоило бы сразу отметить, да. Я просто дальше в проекте про это написал.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Успех 👍:
#
#
#
# 👍
#
#
#
#
# </div>

# %% [markdown]
# В столбце с рейтингом отсутствует 6676 значений. Заменить их на реальные рейтинги или удалить нельзя, так как слишком большой процент от общих данных. Поэтому все значения без рейтинга заменим на "unknown" - неопределенно. Также можно разобрать значения рейтингов: "E" ("everyone") - "Для всех"; "T" ("teen") - "Подросткам"; "M" ("mature") - «Для взрослых»; "E10+" ("everyone 10 and older") - "Для всех от 10 лет и старше"; "EC" ("early childhood") - "Для детей младшего возраста"; "K-A" - (старый вариант маркировки "E"); "AO" ("adults only 18+") - "Только для взрослых"; "RP" ("rating pending") - "Рейтинг ожидается". Здесь мы видим схожие аббревиатуры, которые можно объединить: "K-A" и "E", "M" и "AO", "K-A" и "E", Unknown и "RP".

# %%
games.info()
games.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16444 entries, 0 to 16712
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  int64
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     16444 non-null  float64
#  9   user_score       16444 non-null  float64
#  10  rating           16444 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB
# name               0
# platform           0
# year_of_release    0
# genre              0
# na_sales           0
# eu_sales           0
# jp_sales           0
# other_sales        0
# ...

# %% [markdown]
# Перепроверим данные на их тип и количество пропусков. Где были пропущены значения - добавили. Где нужно было поменять тип данных - поменяли. По итогу мы отсеяли 271 строк с отсутствующими  значениями, что составляет всего лишь 1.62 % процента от всех данных.

# %%
games['amount_sales'] = games['na_sales'] + games['eu_sales'] + games['jp_sales'] + games['other_sales']
#games.head(10)

# %% [markdown]
# Добавим новый столбец с суммарными продажами во всех регионах в наши входные данные.

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Совет:
#
# Твой код отработал норамально, но есть более "пандовский" вариант
# ```
# df[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)
# ```
# где axis = 1 означает что мы считаем по горизонтали, axis = 0 по вертикали.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Совет:
#
# Несколько раз сделана замены пропусков на заглушку в виде цифры. Так можно, но есть неудобный момент. Ведь цифры в месте пропуска  не реальные данные, это заглушка, в итоге при анализе данных столбцов мы должны каждый раз отфильтровывать такие значения, т.к. анализировать их не надо. В итоге, в одном из пунктов можно забыть про такие значения и случайно включить маркерные значения в анализ, что вызовет ошибку в результатах. А с nan не возникнет проблем ни при расчете корреляции, ни при проверке гипотез.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Совет 🤔:
#
#
# В конце раздела рекомендую отправлять промежуточный вывод
# </div>

# %% [markdown]
# # Комментарий студента
# <font color="purple"> Заглушки я дальше блокировал, про питоновский вариант - спасибо! Про выводы - надо бы, я просто всю ману копил на итоговый вывод!

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Успех 👍:
#
#
#
# Так ты пиши промежуточный выводы так, чтобы потом их можно было собрать copypastом  в итоговый вывод ))
#
#
#
#
# </div>

# %% [markdown]
# # Проведем исследовательский анализ данных:

# %%
games.groupby('year_of_release')['name'].count().plot(title='Год выпуска игр', figsize = (15,9), color = 'purple')
games.year_of_release.value_counts()
pass

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
# Успех:
#
#
# График построен хорошо надписи все присутствуют, figsize  подобран.  Почему это может быть важно?! Графики первое что бросается в глаза, а первое впечатление порой определяющее.
#
#
#
#
# <div class="alert alert-warning">
#
#
# Совет:
#
# - Советую использовать [seaborn](https://habr.com/ru/company/otus/blog/540526/).  Он строит красивее, с ним можно строить техничней, он много работы сделает за тебя.

# %% [markdown]
# # Комментарий студента
# <font color="purple"> Спасибо, совет услышал!

# %% [markdown]
# Построим гистаграмму с годами выпуска игр. Мы видим, что больше всего игр выпустили в 2008 году. К 2010 году компьютеры стали мощнее, игры качественней. На гистаграмме мы видим пик, после которого график идет вниз, это может быть связанно с кризисом в 2008 году, который затронул также и игровую индустрию. Брать все периоды для анализа данных не имеет смысла. Да, есть геймеры, которые до сих пор играют в старые игры, но для прогноза продаж на 2017 год они не нужны. Поэтому лучше для дальнейшего анализа брать данные за 2013-2016 год.

# %%
games.groupby('platform').sum()['amount_sales'].sort_values(ascending=False)
# Out:
# platform
# PS2     1233.56
# X360     961.24
# PS3      931.34
# Wii      891.18
# DS       802.78
# PS       727.58
# PS4      314.14
# GBA      312.88
# PSP      289.53
# 3DS      257.81
# PC       255.76
# GB       254.43
# XB       251.57
# NES      251.05
# N64      218.01
# SNES     200.04
# GC       196.73
# XOne     159.32
# 2600      86.48
# WiiU      82.19
# PSV       53.81
# SAT       33.59
# GEN       28.35
# DC        15.95
# SCD        1.86
# NG         1.44
# WS         1.42
# TG16       0.16
# 3DO        0.10
# GG         0.04
# PCFX       0.03
# Name: amount_sales, dtype: float64

# %%
top_games = games.groupby('platform').sum()['amount_sales'].sort_values(ascending=False).index.values[:10]

top_platform = games[games.platform.isin(top_games)]
top_platform = top_platform.pivot_table(index='year_of_release', columns='platform', values='amount_sales', aggfunc='sum')
top_platform.plot(title='Топ-10 платформ по продажам', figsize=(15,9))
pass

# %%
platforms = games.query('platform != "3DS" and platform != "PC" and platform != "PS" and platform != "PS3" and platform != "PS4" and platform != "PSV" and platform != "SAT" and platform != "SNES" and platform != "WiiU" and platform != "X360" and platform != "XOne"')
platform_period = platforms.groupby('platform')['year_of_release'].max() - platforms.groupby('platform')['year_of_release'].min() 
display("Средний период жизни платформы: {} лет".format(platform_period.mean()))
# Out:
# 'Средний период жизни платформы: 7.05 лет'

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
#
#
# Информативный график, и вывод о длине цикла верный.
#
#
#
#
# <div class="alert alert-warning">
#
#
# Совет:
#
#
# Будет гораздо нагляднее, если ты сделаешь этот анализ для 6 платформ с наибольшими продажами в истории. Чтобы получить красивую кривую нужно много данных А многие платформы не имеют большой истории. В результате для них получим что-то статистически не очень достоверное и некрасивое
#
#
# Как можно было найти средний цикл жизни платформ еще?
#
#
#
# - Создать сводную табличку (по одной оси продажи, по другой платформы, а в качестве данных продажи), сверху наложить heatmap - будет красивенько )
#
#
# - По сводной табличке посчитать средний жизненный цикл автоматически.

# %% [markdown]
# # Комментарий студента
# <font color="purple"> Правда, было бы нагляднее. Просто хотелось посмотреть на все, почему-то.

# %% [markdown]
# Если смотреть на все данные от 1980 года, то самой популярной по продажам платформой является PS2. Далее следует X360, PS3, Wii, DS, PS, PS4, GBA, PSP, 3DS. Я бы отметил отдельно PC, которая живет дольше всех платформ. Её нет в топе из-за того, что многие пользователи скачивают пиратские версии, которые никак не входят в статистику продаж. Однако, в последнее время тенденция на покупки лицензированных игр возросла. Также можно отметить, что в среднем платформы живут около 7 лет, далее они либо вообще перестают пользоваться спросом, либо становятся раритетом у геймеров. Также, стоит отметить и PS4, одна из самых успешных платформ выпущенные в последние несколько лет, за небольшой срок своего существования успела влюбить в себя миллионы пользователей по всему миру.

# %%
actual_games = games.query('year_of_release >= 2013')

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
# Для правильного выбора актуальных лет нужно было увязать требование проекта - прогноз на 2017 года, данные о жизненном цикле платформ, особенность индустрии игры, и учесть тренд. Твой выбор верный, молодец.
#
# </div>

# %%
actual_games_platform = (
    actual_games
    .pivot_table(index='platform', values='amount_sales', aggfunc='sum')
    .sort_values('amount_sales', ascending=False)
)
plt.figure(figsize=(15, 9))
(sns.barplot(data = actual_games_platform, x = actual_games_platform.index, y = 'amount_sales', color = 'purple')
    .set(title = 'Топ-10 платформ по продажам за 2013-2016 год', xlabel = 'Платформы', ylabel = 'Общие продажи'))
plt.show()

# %% [markdown]
# Построим столбчатую диаграмму для самых популярных платформ по продажам игр с 2013 по 2016 год. Стоит отметить, что самой популярной платформой является PS4, важность которой мы отмечали в предыдущей диаграмме. Далее расположился PS3, который с каждым годом теряет свою популярность из-за PS4 и новых игр, которые не оптимизированы под данную платформу. Что касается прямого конкурента PS4 за рынок игровой индустрии XOne, он расположился на 3 строчке. 3DS так же входит в наш топ платформ, занимая крепкую позицию лидера, благодаря своей мобильности. X360 также как и PS3 проигрывает своим более новым моделям. WiiU как и 3DS пользуется популярностью из-за своей удобности. Что касается PC, ранее уже определялось главное отличие от других платформ, который проявляется в доступности ко всем играм через пиратские сайты. Также видно, что PSC, Wii, PSP, DS теряют свою из-за конкурентов, которые вышли на новый уровень портативных аналогов домашних консолей. Таким образом, мы имеем 5 основных платформ, на которые мы можем делать акцент при прогнозе на 2017 год. Период с 2013 по 2016 год и будет считаться актуальным периодам, который дальнейшем будет использоваться в исследовании. Ведь хорошая игра живет месяца два-три, отличная игра год, а лучшие пару-тройку лет.

# %%
actual_games_sale = games[(games['year_of_release']>=2013)].copy()
actual_games_sale.pivot_table(index='platform',
                                                               columns='year_of_release',
                                                               values='amount_sales',
                                                               aggfunc='sum').T.plot(title = 'Топ-10 платформ лидирующих по продажам за 2013-2016 год', figsize=(15,9))
pass

# %% [markdown]
# По графику можно выделить перспективные платформы: PS4, XOne, 3DS. Однако, также мы видим, что у всех платформ виден спад. Отдельно, можно отметить PC, который стабильно себя ведет на рынке. У остальных платформ виден резкий спад, что не дает нам  назвать их потенциально прибыльными.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
#
# Посмотрены продажи, динамика и найдены платформы которые действительно стоит рассмотреть для 2017 года.
#
#
#
# PC - вечен )

# %%
plt.figure(figsize=(15, 9))
(sns.boxplot(data = actual_games, y = 'amount_sales', x='platform')
    .set(title = 'Продажи по платформам', xlabel = 'Платформы', ylabel = 'Общие продажи', ylim=(0, 3)))

plt.show()
pass
plt.figure(figsize=(15, 9))
(sns.boxplot(data = actual_games, y = 'amount_sales', x='platform')
    .set(title = 'Продажи по платформам (без выбросов)', xlabel = 'Платформы', ylabel = 'Общие продажи', ylim=(0, 0.9)))

plt.show()
pass

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Ошибка:
#
# График построен верно, но есть одно важное замечание. Результат твоей работы пойдет дальше, например в отдел маркетинга, и там люди вряд ли скажут спасибо за график на котором не видны медиана и квантили. Твой график хорош тем что видны выбросы, они важны, это супермега популярные игры, которые и вытягивают продажи. Но также данный график нужен для сравнения платформ, а на твоем графике такой анализ выполнить затруднительно.
#
# Решением тут будет построить два графика, один с ограниченными данными (без выбросов, чтобы оценить квартили по платформам)  и график с полными данными (для оценки выбросов).
#
# <div class="alert alert-warning">
#
#
# Совет:
#
# почему не используешь seaborn? Он строит красивей и  код лаконичней:
#
#
#     plt.figure(figsize=(13, 8))
#     (sns.boxplot(data = df, y = 'total_sales', x='Платформы')
#         .set(title = 'Продажи по платформам', xlabel = 'Платформы', ylabel = 'Общие продажи', ylim=(0, 3)))
#
#     plt.show()

# %% [markdown]
# Построим график по глобальным продажам игр по платформам. По полученному графику можно сделать вывод, что медиана по продажам на большинстве платформах равняется от 0.1 млн. до 0.4 млн. Сильно уступают остальным конкурентам DS, PSP, PSV. Лидирующие позиции заняли платформы: PS4, XOne, Wii, WiiU, X360, PS3. Это может быть связанно, с дорогой по сравнению с остальными платформами продукцией. PC также не показывает больших продаж, как и отмечалось ранее. Также по графику видно, что медиана на всех платформах близка к нижнему квантилю. Стоит отметить, что в графике присутствуют значения выходящие за пределы 3 квартиля, которые составляют больше 15 миллионов проданных копий. Поэтому стоит отбрасывать те значения, что находятся за верхним усом ящика, так как это самые продаваемые игры.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Успех 👍:
#
#
#
# Теперь на нашей графиках видно всё
#
#
# <div class="alert alert-warning">
#
# Совет:
#
# А вывод можно было дополнить.
# Как видишь для всех платформ медиана ближе к нижнему квантилю, а верхний очень далек, плюс выбросы. Отсюда можем сделать вывод не только что где то больше, где то меньше продажи, где то большая вариативность игры по продажам, где то меньше, но и то что у нас в интервале с небольшими продажами находится очень много игр, а есть суперпупермега популярные игры (выбросы),   продажи которых могут быть выше чем остальные игры вместе взятые. Характеристика это игровой отрасли? Еще какая.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Ошибка:
#
# Boxplot позволяет сравнивать не только по медианам, и сравнивать размахи.
#
# Еще boxplot позволяет сделать выводы о плотности распределения и квантилям.  Стоит добавить анализа, иначе зачем нам вообще boxplot !?
#
# Вопросы, ответы на которые помогут дополнить вывод:
#
# 1. Что общего у плотностей распределений всех платформ (обрати внимание на то к чему ближе медиана - к верхнему или нижнему квантилю)?
#
# 2. Ответив на первый вопрос, можно ли сказать - преобладают ли у нас игры с небольшими продажами и небольшим числом мегапопулярных игр, или наоборот.
#
# Чтобы лучше понять, что отображает боксплот, рекомендую со следующим материалом ознакомиться
#
# https://stepik.org/lesson/9294/step/4?unit=1827
#
# И вот рисуночек:
#
#
# ![Ящик с усами](https://ucarecdn.com/c476e686-fb7b-4e8a-b9d3-54d3b461bb44/)
#
#
#
# </div>

# %% [markdown]
# # Комментарий студента
# <font color="purple"> Посмотрел, вывод к задаче переписал, и правда у нас много мегапопулярных игр!

# %%
PS4 = actual_games.query(
    'platform == "PS4" & critic_score != -10 & user_score != -1 ')
PS4[PS4['critic_score'] != '-10'].plot(
    kind='scatter', 
    x='critic_score', 
    y='amount_sales', 
    figsize = (12,7),
    color = 'purple',
    title = 'Влияние оценок критиков на продажи игр PS4')
PS4[PS4['user_score'] != '-1'].plot(
    kind='scatter', 
    x='user_score',
    y='amount_sales', 
    figsize = (12,7),
    color = 'purple',
    title = 'Влияние оценок критиков на продажи игр PS4')
plt.show()
print(PS4[(PS4['critic_score'] != '-10') 
                        & (PS4['user_score'] != '-1')]
                       [['critic_score', 'user_score', 'amount_sales']].corr()['amount_sales'])
# Out:
# critic_score    0.405895
# user_score     -0.033625
# amount_sales    1.000000
# Name: amount_sales, dtype: float64

# %% [markdown]
# Построим диаграмму рассеяния для взаимосвязи между продажами игр на PS4 и оценками пользователей и критиков. Корреляция между общими продажами и оценкой критиков составляет 0.4 - присутствует слабая связь. Корреляция между общими продажами и оценкой пользователей показывает, что между ними связи отсутствует.

# %%
PS3 = actual_games.query(
    'platform == "PS3" & critic_score != -10 & user_score != -1 ')
PS3[PS3['critic_score'] != '-10'].plot(
    kind='scatter', 
    x='critic_score', 
    y='amount_sales', 
    figsize = (15,9),
    color = 'purple',
    title = 'Влияние оценок критиков на продажи игр PS3')
PS3[PS3['user_score'] != '-1'].plot(
    kind='scatter', 
    x='user_score',
    y='amount_sales', 
    figsize = (15,9),
    color = 'purple',
    title = 'Влияние оценок критиков на продажи игр PS3')
plt.show()
print(PS3[(PS3['critic_score'] != '-10') 
                        & (PS3['user_score'] != '-1')]
                       [['critic_score', 'user_score', 'amount_sales']].corr()['amount_sales'])
# Out:
# critic_score    0.333807
# user_score      0.022691
# amount_sales    1.000000
# Name: amount_sales, dtype: float64

# %% [markdown]
# Построим диаграмму рассеяния для взаимосвязи между продажами игр на PS3 и оценками пользователей и критиков. Корреляция между общими продажами и оценкой критиков составляет 0.3 - присутствует слабая связь. Корреляция между общими продажами и оценкой пользователей показывает, что между ними есть слабая связь.

# %%
XOne = actual_games.query(
    'platform == "XOne" & critic_score != -10 & user_score != -1 ')
XOne[XOne['critic_score'] != '-10'].plot(
    kind='scatter', 
    x='critic_score', 
    y='amount_sales', 
    figsize = (15,9),
    color = 'purple',
    title = 'Влияние оценок критиков на продажи игр XOne')
XOne[XOne['user_score'] != '-1'].plot(
    kind='scatter', 
    x='user_score',
    y='amount_sales', 
    figsize = (15,9),
    color = 'purple',
    title = 'Влияние оценок критиков на продажи игр XOne')
plt.show()
print(XOne[(XOne['critic_score'] != '-10') 
                        & (XOne['user_score'] != '-1')]
                       [['critic_score', 'user_score', 'amount_sales']].corr()['amount_sales'])
# Out:
# critic_score    0.410422
# user_score     -0.094003
# amount_sales    1.000000
# Name: amount_sales, dtype: float64

# %% [markdown]
# Построим диаграмму рассеяния для взаимосвязи между продажами игр на XOne и оценками пользователей и критиков. Корреляция между общими продажами и оценкой критиков составляет 0.4 - присутствует слабая связь. Корреляция между общими продажами и оценкой пользователей показывает, что между ними связи отсутствует.

# %%
DS = actual_games.query(
    'platform == "3DS" & critic_score != -10 & user_score != -1 ')
DS[DS['critic_score'] != '-10'].plot(
    kind='scatter', 
    x='critic_score', 
    y='amount_sales', 
    figsize = (15,9),
    color = 'purple',
    title = 'Влияние оценок критиков на продажи игр 3DS')
DS[DS['user_score'] != '-1'].plot(
    kind='scatter', 
    x='user_score',
    y='amount_sales', 
    figsize = (15,9),
    color = 'purple',
    title = 'Влияние оценок критиков на продажи игр 3DS')
plt.show()
print(DS[(DS['critic_score'] != '-10') 
                        & (DS['user_score'] != '-1')]
                       [['critic_score', 'user_score', 'amount_sales']].corr()['amount_sales'])
# Out:
# critic_score    0.339235
# user_score      0.272990
# amount_sales    1.000000
# Name: amount_sales, dtype: float64

# %% [markdown]
# Построим диаграмму рассеяния для взаимосвязи между продажами игр на 3DS и оценками пользователей и критиков. Корреляция между общими продажами и оценкой критиков составляет 0.3 - присутствует слабая связь. Корреляция между общими продажами и оценкой пользователей также показывает слабую связь.

# %%
X360 = actual_games.query(
    'platform == "X360" & critic_score != -10 & user_score != -1 ')
X360[X360['critic_score'] != '-10'].plot(
    kind='scatter', 
    x='critic_score', 
    y='amount_sales', 
    figsize = (15,9),
    color = 'purple',
    title = 'Влияние оценок критиков на продажи игр X360')
X360[X360['user_score'] != '-1'].plot(
    kind='scatter', 
    x='user_score',
    y='amount_sales', 
    figsize = (16,9),
    color = 'purple',
    title = 'Влияние оценок критиков на продажи игр X360')
plt.show()
print(X360[(X360['critic_score'] != '-10') 
                        & (X360['user_score'] != '-1')]
                       [['critic_score', 'user_score', 'amount_sales']].corr()['amount_sales'])
# Out:
# critic_score    0.350345
# user_score     -0.006238
# amount_sales    1.000000
# Name: amount_sales, dtype: float64

# %% [markdown]
# Построим диаграмму рассеяния для взаимосвязи между продажами игр на X360 и оценками пользователей и критиков. Корреляция между общими продажами и оценкой критиков составляет 0.35 - присутствует слабая связь. Корреляция между общими продажами и оценкой пользователей показывает, что между ними связи отсутствует.

# %%
Wiiu = actual_games.query(
    'platform == "WiiU" & critic_score != -10 & user_score != -1 ')
Wiiu[Wiiu['critic_score'] != '-10'].plot(
    kind='scatter', 
    x='critic_score', 
    y='amount_sales', 
    figsize = (15,9),
    color = 'purple',
    title = 'Влияние оценок критиков на продажи игр WiiU')
Wiiu[Wiiu['user_score'] != '-1'].plot(
    kind='scatter', 
    x='user_score',
    y='amount_sales', 
    figsize = (16,9),
    color = 'purple',
    title = 'Влияние оценок критиков на продажи игр WiiU')
plt.show()
print(Wiiu[(Wiiu['critic_score'] != '-10') 
                        & (Wiiu['user_score'] != '-1')]
                       [['critic_score', 'user_score', 'amount_sales']].corr()['amount_sales'])
# Out:
# critic_score    0.379504
# user_score      0.408692
# amount_sales    1.000000
# Name: amount_sales, dtype: float64

# %% [markdown]
# Построим диаграмму рассеяния для взаимосвязи между продажами игр на WiiU и оценками пользователей и критиков. Корреляция между общими продажами и оценкой критиков составляет 0.37 - присутствует слабая связь. Корреляция между общими продажами и оценкой пользователей также показывает слабую связь.

# %%
PC = actual_games.query(
    'platform == "PC" & critic_score != -10 & user_score != -1 ')
PC[PC['critic_score'] != '-10'].plot(
    kind='scatter', 
    x='critic_score', 
    y='amount_sales', 
    figsize = (15,9),
    color = 'purple',
    title = 'Влияние оценок критиков на продажи игр PC')
PC[PC['user_score'] != '-1'].plot(
    kind='scatter', 
    x='user_score',
    y='amount_sales', 
    figsize = (16,9),
    color = 'purple',
    title = 'Влияние оценок критиков на продажи игр PC')
plt.show()
print(PC[(PC['critic_score'] != '-10') 
                        & (PC['user_score'] != '-1')]
                       [['critic_score', 'user_score', 'amount_sales']].corr()['amount_sales'])
# Out:
# critic_score    0.194124
# user_score     -0.109235
# amount_sales    1.000000
# Name: amount_sales, dtype: float64

# %% [markdown]
# Построим диаграмму рассеяния для взаимосвязи между продажами игр на PS и оценками пользователей и критиков. Корреляция между общими продажами и оценкой критиков составляет 0.19 - присутствует слабая связь. Корреляция между общими продажами и оценкой пользователей показывает, что между ними связи отсутствует.

# %%
print(actual_games['critic_score'].corr(games['amount_sales']))
print(actual_games['user_score'].corr(games['amount_sales']))
# Out:
# 0.21546011813930036
# 0.1552266291531267

# %% [markdown]
# Посмотрим на общую корреляцию между отзывами и продажами. Корреляция между общими продажами и оценкой критиков составляет 0.21, это говорит об слабой связи. Корреляция между общими продажами и оценкой критиков ниже (0.21), что также говорит об низкой связи между ними. Разберемся с этим вопросом более подробно. В игровой индустрии оценки не сильно влияют на продажи игр, например, FIFA (футбольный симулятор) имеет плохие оценки от пользователей, однако, это не мешает ей быть одной из популярных игр в мире. Покупая игру, смотрят не на отзывы пользователей и критиков, а на сам продукт, для многих важно: оформление, геймлей, сюжет, содержание. Для других это любовь к какой-то серии игр, например Call Of Duty. Также, можно заметить, что на рынке игровой индустрии важна популяризация продукта, сюда можно отнести стриминговые площадки, где стримеры играя, продвигают продукты в массы. Отсюда и такая маленькая взаимосвязь между оценками пользователей, критиков и общими продажами.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
#
# + заглушки убраны
#
# + сила связи описана правильно
#
# + отсутствие корреляции между отзывами клиентов и продажами подчеркнута правильно
#
# + графики оформлены аккуратно
#
# + метод .corr() использован
#
#
#
#
# <div class="alert alert-warning">
#
#
# Совет:
#
#
# - Когда действие повторяется два и более раз, стоит подумать о цикле или функции или функции с циклом
#
#
#
#
# Вопросики, пожеланию можешь ответить )
#
#
#
#
# - Можешь вспомнить, только какой тип связи может выявить корреляция Пирсона?
#
#
# - Можно ли утверждать о отсутствии связи при близких к нулю показателях корреляции?
#
#
# - Можно ли утверждать о причинно-следственной связях при высоких значениях корреляции?
#
#
# - Можешь используя графики выявить нелинейные связи?
#
#
#
#
# </div>

# %% [markdown]
# # Комментарий студента
# <font color="purple"> Стоит подумать о циклах, но пока я не очень с ними дружу(
# Ответы на вопросики:
#     1. Линейная (и все).
#     2. Можно утверждать, что нет линейной связи, но не общую связь между ними.
#     3. Можно утверждать, ведь причинно-следственная связь должна говорить о том, что у них высокое значения корреляции.
#     4. Думаю если есть метод показа линейной связи, то должен быть метод показа нелинейной связи (Но, боюсь, я не смогу без помощи интернета сказать как)

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
# Успех:
#
#
# 1. Все верно, Пирсон говорит лишь о линейной связи между данными
#
#
# 2. Да.
#
#
# 4. Нет,  что причина, а что следствие мы понятия не имеем. Более того причиной может быть какой то третий фактор
#
#
# 5. Можно таким образом: на некоторых scatter графиках мы можем увидеть, пока рейтинг ниже 60-80, нет прямой зависимости между ростом оценок и продаж, а после 80, большему рейтингу начинают соответствовать большие продажи - вот такой вид нелинейной связи. Тут как видишь всё на глазок )
#
#
# </div>

# %%
actual_genre_platform = (
    actual_games
    .pivot_table(index='genre', values='amount_sales', aggfunc='sum')
    .sort_values('amount_sales', ascending=False)
)
plt.figure(figsize=(15, 9))
(sns.barplot(data = actual_genre_platform, x = actual_genre_platform.index, y = 'amount_sales', color = 'purple')
    .set(title = 'Распределение продаж игр по жанрам за 2013-2016 год', xlabel = 'Жанры', ylabel = 'Общие продажи'))
plt.show()

# %%
actual_games.boxplot(by='genre', column='amount_sales', figsize=(15,9), fontsize=12)
pass

# %%
actual_games.groupby('genre').mean()['amount_sales'].sort_values(ascending=False)
# Out:
# genre
# Shooter         1.245882
# Sports          0.703972
# Platform        0.576081
# Role-Playing    0.499623
# Racing          0.469294
# Fighting        0.441375
# Action          0.420196
# Misc            0.405290
# Simulation      0.350968
# Puzzle          0.186471
# Strategy        0.180000
# Adventure       0.096490
# Name: amount_sales, dtype: float64

# %% [markdown]
# Построим столбчатую диаграмму для самых популярных жанров по продажам игр с 2013 по 2016 год. Выделим 4 основных жанра, которые приносят больше всех продаж: shooter(стрелялки), sports(спорт), platform (Платформер), (role-playing(ролевые). У всех остальных жанров примерно одинаковые медианные показатели. Также стоит учитывать, что игр по популярным жанрам больше на рынке игровой индустрии, отсюда и такая разница по показателям.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Успех 👍:
#
#
#
#
# Да, оказывается cамые популярные игры жанра шутеры, а игры жанра Action имеет довольно средний показатель продаж.  Смотреть средние важно потому что мы продаём конкретные игры, а не жанры
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Ошибка:
#
# Верно ли ограничиваться сравнением суммарных продаж по жанрам (по boxplot медиана плохо видна)?! На какие множители можно разложить полученный результат?! Это средняя продажа игр в этом жанре на количество игр в этом жанре. То есть за высокими продажами какого-то жанра могут скрываться множество мелких игры, с низкими продажами. А за низкими суммарными продажами в жанре может скрываться небольшое число игры, но каждая из которых имеет высокие доходы.  Посмотри на средние продажи (aggfunc='mean') и оцени, как поменяются лидеры.
#
#
# </div>

# %% [markdown]
# # Комментарий студента
# <font color="purple"> Посмотрел на средние продажи, и правда изменились лидеры (вывод переписал)

# %% [markdown]
# # Составим портрет пользователя каждого региона:

# %%
regions = actual_games.columns[4:7]
fig, axs = plt.subplots(1, 3, figsize=(16, 5))
fig.suptitle('ТОП-5 платформ в регионах')
for reg in range(3):
  region = (actual_games.groupby('platform')[regions[reg]].sum().
             reset_index().
             sort_values(regions[reg], ascending = False, ignore_index = True).
             head(5))
  region = region.append({'platform': 'other', regions[reg]: actual_games[regions[reg]].sum() - region[regions[reg]].sum()}, ignore_index= True)
  axs[reg].pie(region[regions[reg]], labels = region['platform'])
  axs[reg].pie(region[regions[reg]], labels = region['platform'], autopct='%.2f%%')
  axs[reg].set_title(region.columns[1].split('_')[0].upper())
plt.show()

# %% [markdown]
# Построим круговую диаграмму популярных платформ в регионах. В регионе NA (Северная Америка) преобладают платформы PS4 и XOne, далее идут X360 и PS3. Можно отметить, что стационарные приставки в данном регионе пользуются большим спросом чем портативные приставки. Также по диаграмме видно, что стационарные приставки нового поколения (PS4, XOne) преобладают над своими старыми версиями и занимают 46.1% от общего рынка продаж. Остальные платформы занимают 11.99% доли продаж.
# В Регионе EU (Европа) схожая ситуация, PS4 также имеют большую долю продаж, что касается XOne, в данном регионе популярность меньше чем в NA. PS3 занимает 17.29% от общей доли, что делает её второй по популярности платформе. Также видна тенденция перехода от старых приставок к новому поколению, и преобладание их над портативными приставками. Остальные платформы занимают 14.85% доли продаж.
# В Регионе JP(Япония) картина отличается. Половину доли занимает портативная приставка 3DS (48.17%). Далее идет PS3 (16.59%) и PSV (13.21%). Если PS4 в NA и EU занимало первое место по доле продаж, то здесь мы видим, что стационарная приставка расположились на 4 месте (11.34%). Также если в других регионах стационарные приставки преобладали над портативными, то В JP ситуация другая, портативные приставки занимают 67.1% от общей доли продаж, что делает их главными игроками на рынке игровой индустрии.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
#
#
# Техничная реализация - subplots, циклы  - все по фэн шую )
#
#
#
#
# </div>

# %%
fig, axs = plt.subplots(1, 3, figsize=(16, 5))
fig.suptitle('ТОП-5 жанров в регионах')
for reg in range(3):
  region = (actual_games.groupby('genre')[regions[reg]].sum().
             reset_index().
             sort_values(regions[reg], ascending = False, ignore_index = True).
             head(5))
  region = region.append({'genre': 'other', regions[reg]: actual_games[regions[reg]].sum() - region[regions[reg]].sum()}, ignore_index= True)
  axs[reg].pie(region[regions[reg]], labels = region['genre'])
  axs[reg].pie(region[regions[reg]], labels = region['genre'], autopct='%.2f%%')
  axs[reg].set_title(region.columns[1].split('_')[0].upper())
plt.show()

# %% [markdown]
# Построим круговую диаграмму популярных жанров в регионах. В регионе NA (Северная Америка) преобладают жанры Shooter(стрелялки) и Action(экшен), далее идут Sports(спортивные) и Role-Playing(ролевые). Остальные жанры занимают 14.34% доли продаж. В Регионе EU (Европа) похожая ситуация, Shooter(стрелялки) и Action(экшен) также преобладают на рынке. Далее идут Sports(спортивные) и Racing(гонки). Остальные жанры занимают 17.48% доли продаж. В Регионе JP(Япония) картина вновь отличается. Role-Playing(ролевые) преобладают над остальными жанрами. На втором месте расположился жанр action(экшен). Если в других регионах жанр Shooter(стрелялки) имел большую долю продаж, то В JP ситуация другая, стрелялки имеют 4.7% от общей доли продаж. Остальные жанры занимают 18.32% доли продаж.

# %%
fig, axs = plt.subplots(1, 3, figsize=(16, 5))
fig.suptitle('ТОП-5 рейтингов игр в регионах')
for reg in range(3):
  region = (actual_games.groupby('rating')[regions[reg]].sum().
             reset_index().
             sort_values(regions[reg], ascending = False, ignore_index = True).
             head(5))
  axs[reg].pie(region[regions[reg]], labels = region['rating'])
  axs[reg].pie(region[regions[reg]], labels = region['rating'], autopct='%.2f%%')
  axs[reg].set_title(region.columns[1].split('_')[0].upper())
plt.show()

# %% [markdown]
# Построим круговую диаграмму популярных рейтингов в регионах. По диаграммам, можно сказать, что рейтинг ESRB имеет небольшую роль при продажах. Распределение ESRB среди рейтингов в регионах примерно одинаковое. Однако, в регионе JP (Япония) вновь ситуация отличается, ведь компания ESRB оценивает продукцию Американских и Канадских компаний. Также стоит отметить, что в NA (Северная Америка) и EU (Европа) преобладают игры для взрослых. В JP (Япония) преобладают игры для подростков.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
# Япония на своей волне ) И жанры другие и платформы и доля играющих среди тинейджеров выше
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Совет:
#
#
#
#
#
# - Допустим мы хотим cделать группировку и вывести в процентах. Мы можем взять сумму (sum), среднюю (mean)...но чтобы сделать проценты, придётся поработать похитрее (схема):
#
#         (df_current
#         .groupby('platform')[['na_sales', 'eu_sales', 'jp_sales']]
#         .agg('sum')
#         .apply(lambda x: round(x / float(x.sum()), 2))     # вот это считает проценты
#         ).reset_index()
#
#
# Лямбда функция это очень просто, ты ведь знаешь про самописные функции? Так вот лямбда это "функция на лету", можно написать функцию, а можно лямбду, аналогии очевидны:
#
#         def add_(x):
#             return x+3
#
# и аналог
#
#         lambda x: x+3
#
# Как видишь мы не создаем функцию, не присваиваем ей имя, не пишем return, мы просто быстренько сделали неименованную функцию - лямбду, потому что больше она нам не понадобиться, а аргумент x и там и там один и тот же и делаем мы с ним одно и тоже.
#
#
#
# - Рейтинги `E`, `T`, `K-A` итд  могут нам ничего не говорить,  тавай сделаем замену: E  ----->  Для всех, M ------>   17 лет итп. Обычно используют для этого словарь с заменами и .map (схема):
#
#
#
#         ESRB_dict = {'E': 'Для всех', 'M': '> 17 лет', 'T': '13-19 лет', 'E10+': '>10 лет', 'K-A': 'Для всех', 'unknown': 'Не известен',....}
#         df_current['ESRB_description'] = df_current['rating'].map(ESRB_dict)
#
#
#
#
#
#
#
# Это не обязательное требование, если есть желание можешь попробовать что то реализовать, нет - я приму работу и так ;)
#
#
# </div>

# %% [markdown]
# # Комментарий студента
# <font color="purple"> Ух ты, я заскринил ваш способ, спасибо! Буду на него отсылаться в похожих задачах!

# %% [markdown]
# # Проверим гипотезы:

# %%
plat = actual_games[actual_games['user_score'] != -10]
results = st.ttest_ind(
    plat.query('platform == "XOne"')['user_score'], 
    plat.query('platform == "PC"')['user_score'], equal_var=False)

alpha = 0.05
print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.19564149183065668
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Нулевая гипотеза (H0): Средние пользовательские рейтинги платформ XOne и PC одинаковые.
# Альтерантивная гипотеза (H1): Средние пользовательские рейтинги платформ XOne и PC отличаются.
# Полученное значение p-value (0.19). Это говорит о том, что отвергнуть нулевую гипотезу не получится. Нулевой гипотезой здесь является выражение: "Средние пользовательские рейтинги платформ XOne и PC одинаковые". Получается, что нет оснований предполагать, что средние пользовательские рейтинги сильно отличаются. Альтернативной гипотезой являлось бы выражение: "Средние пользовательские рейтинги платформ XOne и PC различаются". Для сравнения статистик заданных платформ нужно использовать t-test, так как мы сравниваем две выборки.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
#
#
# Правильно:
#
# + сформулирована нулевая и альтернативные гипотезы
#
# + правильно выбрана статистика
#
# + метод
#
# + equal_var=False

# %%
results = st.ttest_ind(
    plat.query('genre == "Action"')['user_score'], 
    plat.query('genre == "Sports"')['user_score'], equal_var=False)

alpha = 0.05
print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.008445505365573197
# Отвергаем нулевую гипотезу

# %% [markdown]
# Нулевая гипотеза (H0): Средние пользовательские рейтинги жанров Action и Sports одинаковые.
# Альтерантивная гипотеза (H1): Средние пользовательские рейтинги жанров Action и Sports отличаются.
# Полученное значение p-value (0.08). Это говорит о том, что  мы можем отвергнуть нулевую гипотезу. Нулевой гипотезой здесь является выражение: "Средние пользовательские рейтинги жанров Action и Sports разные". Получается, что нет оснований предполагать, что средние пользовательские рейтинги данных жанров сильно отличаются. Альтернативной гипотезой являлось бы выражение: "Средние пользовательские рейтинги жанров Action и Sports различаются". Для сравнения статистик заданных жанров нужно использовать t-test, так как мы сравниваем две выборки.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
# Выводы точные, без глупостей: "подтвердили гипотезу..", "выяснили что рейтинги равны/неравны.." )
#
#
# </div>

# %% [markdown]
# # Вывод:

# %% [markdown]
# В ходе работы было проведено исследование выявления особенностей и закономерностей на рынке игровой индустрии, для дальнейшего планирование рекламной кампании и выявления потенциально успешного продукта. Входные данные  — открытые источники данных о продажах игр, оценке пользователей и экспертов, жанры и платформы. Перед началом исследование необходимо было обработать входные данные. В ходе работы были обработаны пропущенные значения, заменены типы данных для простоты исследования. Посчитано и добавлено в таблицу новый столбец: суммарные продажи во всех регионах. Также были исправлены значения в столбцах: год, название игр. Заглушены пропущенные значения в столбцах: оценки критиков, пользовательские оценки, рейтинг игр. После всех исправлений можно приступать к исследованию по выявлению особенностей и зависимостей на рынке игровой индустрии.
#
# При проведении исследовательского анализа данных были выявленные следующие закономерности:
#    1. Выпуск игр в разные годы:
#    Больше всего игр выпустили в 2008 году. Также был спад, связанный с кризисом в 2008 году, который затронул также и игровую индустрию.
#    2. Общие продажи по платформам:
#    Если смотреть на все данные от 1980 года, то самой популярной по продажам платформой является PS2. Далее следует Xbox360, PS3, Wii, DS, PS, PS4, GBA, PSP, 3DS. Также стоит отметить PC, которая живет дольше всех платформ, однако отсутствует в топе платформ из-за существующего пиратских сайтов. В среднем платформы живут около 7 лет. Отдельно стоит отметить и PS4, которая является самой успешной платформой выпущенной в последние несколько лет.
#    3. Выпуск игр и общие продажи по платформам за актуальный период:
#    Брать все периоды для анализа данных не имеет смысла. Для прогноза продаж на 2017 год они не нужны. Полезней для дальнейшего анализа брать данные за 2013-2016 год. Самой популярной платформой является PS4. Далее расположился PS3, который с каждым годом теряет популярность из-за PS4 и новых игр, которые не оптимизированы под данную платформу. Что касается прямого конкурента PS4 за рынок игровой индустрии XOne, он расположился на 3 строчке. 3DS входит в наш топ платформ, занимая крепкую позицию лидера, благодаря Японскому рынку игровой индустрии. X360 так же как и PS3 проигрывает своим более новым моделям. WiiU, как и 3DS пользуется популярностью из-за своей удобности. Что касается PC, ранее уже определялось главное отличие от других платформ, который проявляется в доступности ко всем играм через пиратские сайты. Также видно, что PSC, Wii, PSP, DS теряют свою из-за конкурентов, которые вышли на новый уровень портативных аналогов домашних консолей.  Таким образом, можно выделить перспективные платформы на следующий год: PS4, XOne, 3DS. Отдельно, можно отметить PC, который стабильно себя ведет на рынке. У остальных платформ виден резкий спад, что не дает нам назвать их потенциально прибыльными.
#    4. Потенциально прибыльные платформы и их глобальные продажи:
#    Медиана по продажам на большинстве платформах равняется от 0.1 млн. до 0.4 млн. Сильно уступают остальным конкурентам DS, PSP, PSV. Лидирующие позиции заняли платформы: PS4, XOne, Wii, WiiU, X360, PS3. PC также не показывает больших продаж, как и отмечалось ранее. Также медиана на всех платформах близка к нижнему квантилю. Стоит отметить, что в графике присутствуют значения выходящие за пределы 3 квартиля, которые составляют больше 15 миллионов проданных копий.
#    5. Корреляция между отзывами и продажами:
#    Корреляция между общими продажами и оценкой критиков составляет 0.21, это говорит об слабой связи. Корреляция между общими продажами и оценкой критиков ниже (0.21), что также говорит об низкой связи между ними.
#    6. Общее распределение игр по жанрам:
#    Выделяются 4 основных жанра, которые приносят больше всех продаж: shooter(стрелялки), sports(спорт), platform (Платформер), role-playing(ролевые). У всех остальных жанров примерно одинаковые медианные показатели.
#
#    Также можно составить портреты пользователей регионов представленных в наших данных:
#    Портрет пользователя NA:
#    Предпочитает PS4, жанры: Action(экшен), Shooter(стрелялки), Sports(спортивные) и Role-Playing(ролевые).
#    Портрет пользователя EU:
#    Предпочитает PS4, жанры: Action(экшен), Shooter(стрелялки), Sports(спортивные) и Role-Playing(ролевые).
#    Портрет пользователя JP:
#    Предпочитает 3DS, жанры: Role-Playing(ролевые), Action(экшен).
#
#
#
#
# Перед проведением исследования были поставлены следующие гипотезы:
#    1. Средние пользовательские рейтинги платформ XOne и PC одинаковые.
#    Гипотеза 1 подтверждена: Полученное значение p-value (0.19).
#    Это говорит о том, что отвергнуть нулевую гипотезу не получится. Нулевой гипотезой здесь является выражение: "Средние пользовательские рейтинги платформ XOne и PC одинаковые". Получается, что нет оснований предполагать, что средние пользовательские рейтинги сильно отличаются. Альтернативной гипотезой являлось бы выражение: "Средние пользовательские рейтинги платформ XOne и PC различаются".
#    2. Средние пользовательские рейтинги жанров Action(экшен) и Sports(спортивные) отличаются.
#    Гипотеза 2 не подтверждена: Полученное значение p-value (0.08).
#    Это говорит о том, что мы можем отвергнуть нулевую гипотезу. Нулевой гипотезой здесь является выражение: "Средние пользовательские рейтинги жанров Action и Sports разные". Получается, что нет оснований предполагать, что средние пользовательские рейтинги данных жанров сильно отличаются. Альтернативной гипотезой являлось бы выражение: "Средние пользовательские рейтинги жанров Action и Sports различаются".
#
#    Общие рекомендации: Таким образом мы получили данные, которые позволяют зафиксировать особенности и закономерности на рынке игровой индустрии, для дальнейшего планирование рекламной кампании и выявления потенциально успешного продукта. Рекламная кампания и потенциально успешный продукт на 2017 год выглядит следующим образом: Акцент на платформы: PS4, XOne, 3DS,  PC, PS3, X360. Популярные жанры: Action(экшен), Shooter(стрелялки), Sports(спортивные) и Role-Playing(ролевые). Также для каждого региона обязательно учитывать полученный портрет пользователя.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
# Расписаны все этапы работы, есть конкретные рекомендации, и анализ с объяснением причин. Хороший, по делу, "без воды" вывод. Почему это важно? Когда проект захочет посмотреть будущий работодатель, у него может не быть времени на подробный разбор кода. Вероятнее всего он бегло просмотрит код, но захочет изучить результат, который будет в общем выводе. Поэтому стоит обратить на общий вывод особое внимание.
#
#
# Но после исправления красных комментариев выше, стоит ещё раз пробежать его взглядом.

# %% [markdown]
# <div class="alert alert-info">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Самое большое впечатление от твоего проекта - старательность при выполнении работы над ним, не пожалел ни времени, ни усилий. Очень тщательный подход к очистке данных, бережное отношение к ним, буквально ничего не пропало. Все промежуточные и основные выводы сделаны, инструменты и методы модуля использованы оптимально.
#
#
#
# Ты умело применяешь графические библиотеки (matplotlib / seaborn), выбираешь для визуализации ровно те типы графиков, которые нужны, используешь subplot. Оформление графиков очень аккуратное.
#
# Наиболее тонкое место в проекте - работа с пропусками тобой выполнена без ошибок
#
#
# Эд, отмечаю уровень твоей программистской подготовки, - ты используешь продвинутые концепции языка Python и библиотеки pandas, всё это делает более читабельным твой код и одновременно показывает твой уровень владения инструментами.
#
#
#
#
# Советую пользоваться возможностями питона, который позволяет избегать излишнее использование циклов, apply, map итп. Питон вообще такой язык, на котором, если поискать, почти всегда найдется метод или библиотека чтобы написать решение чуть ли не в одну строчку. Не всегда такое возможно, но стремиться стоит.
#
#
#
#
# Замечания на будущее:
#
# - Комментарии к коду отсутствуют - коллеги могут не понять хода твоих мыслей. Пока код простой, но дальше он будет усложняться и в нужных местах оставлять пояснения можно начинать ставить уже сейчас
#
#
#
#
# Остались небольшие недоработки. Стоит доделать:
#
# - Не забываем хорошо начать - `вступление в работу` очень важно
#
# - Исправить `график boxplot`  с соответствии с моими комментариями, и добавляем анализ
#
# - Добавить анализ `средних` продаж по жанрам.
#
# - "В свете вновь открывшихся обстоятельств" `поправить` выводы где это необходимо
#
#
# Уверен, тебе не составит большого труда внести исправления. Жду их, для принятия проекта. Удачи 😀
#
# </div>

# %% [markdown]
# # Комментарий студента
# <font color="purple"> Марат, спасибо больше за такую оценку и теплые слова! Недоработки исправил (надеюсь, что правильно), рекомендации буду учитывать обязательно. И спасибо за полезную информацию! В следующий раз начну комментировать коды (до этого не просили).

# %% [markdown]
# <div class="alert alert-info">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
# Спасибо за работу!   Насчёт комментирования кода - это ты сам смотришь гже и как. Если есть какие-то моменты в коде, которые ты хочешь объяснить другим или даже себе памятку, чтобы было проще вспоминать потом. То есть тут нет такого что написал код - и сразу его объясняешь. Крайности не нужны
#
#
# Красное исправлено (их было ооочнеь мало), многие желтые советы использованы, на  вопросы есть ответы  (это все было по желанию), значит стремишься развиваться, а желание и интерес это главное. Надеюсь мои советы и вопросики были полезны и в копилочку знаний упало что то новое, а проект стал лучше, и симпатичней.
#
#
#
# Отличная работа Эд. Желаю успехов в дальнейшей учебе!
