# %% [markdown]
# <div style="background:#d4d6fa; color:#000; padding:10px">
#     <p><big><b> Комментарий тимлида: </b></big></p>
# Здравствуй, Эдгар! Меня зовут Москвин Антон! Я буду использовать стандартную цветовую разметку комментариев:
# <div class="alert alert-success">
#         <strong>👍 Зелёным</strong> цветом я буду выделять удачные и элегантные решения, на которые можно опираться в будущих проектах.
#     </div>
#     <div class="alert alert-warning">
#         <strong>⚠️Желтым</strong> будет выделено то, что в следующий раз стоит сделать по-другому. Одно-два таких замечаний в проекте допустимы, но если их будет больше, то нужно будет внести изменения.
#     </div>
#     <div class="alert alert-danger">
#         <strong>⛔️Красным</strong> - то, что необходимо исправить, прежде чем я смогу принять твой проект.
#     </div>
# Пожалуйста, НЕ УДАЛЯЙ и НЕ ПЕРЕДВИГАЙ их.
#     <br>СЛЕДУЮЩИЙ этап должен выполняться В ЭТОМ же ноутбуке! На следующем этапе у тебя откроется пустой ноутбук, тебе нужно загрузить туда свою работу с прошлого этапа и продолжить работать!
# </div>

# %% [markdown]
# # Сегментация пользователей Метанпромбанка по потреблению

# %% [markdown]
# <div class='alert alert-success'> 👍
# Спасибо за описание задачи! Помни что основная цель аналитики это снизить отток, выделение сегментов нужно для формирования более релевантных предложений которые помогут удержать клиентов.

# %% [markdown]
# В нашем распоряжении имеются данные о клиентах Метанпромбанка. Банк расположен в Ярославле, Ростове, Великом и Рыбинске. В последнее время банк теряет своих клиентов. Нам необходимо провести анализ поведения клиентов, сегментировать, и составить их характерные портреты для выработки решения для улучшения нынешней ситуации. Во время анализа мы будем работать с предоставленным датасетом с данными о клиентах. После исследования мы сможем составить характерный портрет клиента,   положительные и отрицательные показатели. Далее подготовим рекомендации для улучшения ситуации с удержанием клиентов Метанпромбанка.

# %% [markdown]
# ### Цель исследования:

# %% [markdown]
# Сегментировать характерные признаки клиентов Метанпромбанка и поиск эффективного решения для удержания клиентов. Также сформулировать и проверить статистические гипотезы.

# %% [markdown]
# ### Описание предоставленных данных:

# %% [markdown]
# 1. user_id — идентификатор пользователя;
# 2. score — баллы кредитного скоринга;
# 3. city — город;
# 4. gender — пол;
# 5. age — возраст;
# 6. equity — баллы объектов в собственности;
# 7. balance — баланс на счёте;
# 8. products — количество продуктов, которыми пользуется клиент;
# 9. credit_card — наличие кредитной карты;
# 10. last_activity — активный клиент;
# 11. estimated_salary — заработная плата клиента;
# 12. churn — ушёл клиент или нет.

# %% [markdown]
# <div class='alert alert-success'> 👍
# Мне понравился твой план, тебе удалось корректно произвести декомпозицию поставленной задачи. Продолжай работать в соответствии с пунктами получившегося плана!

# %% [markdown]
# ### План исследования:

# %% [markdown]
# #### Загрузка библиотек и изучение информации предоставленных данных.

# %% [markdown]
# #### Предобработка предоставленных данных:

# %% [markdown]
# 1. Привести столбцы к единому стилю;
# 2. Проверить типы данных и изменить при необходимости;
# 3. Проверить пропуски в данных, при необходимости заполнить или удалить их;
# 4. Проверить явные/неявные дубликаты, при необходимости их обработать;
# 5. Исследовать аномалии в данных.

# %% [markdown]
# #### Иследовательский анализ предоставленных данных:

# %% [markdown]
# 1. Составить характерный портрет пользователей банка;
# 2. Построить распределение клиентов по городам, полу, активности, наличии кредитной карты, уходу из банка;
# 3. Изучить распределение клиентов по баллам кредитного скоринга, возрасту, балансу на счете, зарплате;
# 4. Сопоставить все полученные признаки с оттоком клиентов из банка, посчитать корреляцию, проанализировать зависимости между полученными данными.

# %% [markdown]
# #### Промежуточные выводы по исследованию.

# %% [markdown]
# #### Сегментация клиентов банка по потреблению:

# %% [markdown]
# 1. Провести сегментацию клиентов банка в разрезе числа используемых продуктов;
# 2. Проанализировать признаки в разрезе количества потребляемых продуктов банка клиентамию.

# %% [markdown]
# #### Выделить сегменты, проанализировать их, написать промежуточные выводы по исследованию.

# %% [markdown]
# #### Проверка статистических гипотез.

# %% [markdown]
# #### Составить выводы и рекомендации.
